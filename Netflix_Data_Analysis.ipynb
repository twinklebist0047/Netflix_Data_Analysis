# %% [markdown]
# # Netflix_Data_Analysis

# %%
# Importing python libraries
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
# Importing Data file
df = pd.read_csv('netflix_titles.csv')
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# # Exploring data

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# # Data Cleaning

# %%
df['date added'] = pd.to_datetime(df['date_added'])

# %%
df[['director', 'cast', 'country', 'date_added', 'rating']] = df[['director', 'cast', 'country', 'date_added', 'rating']].fillna('unavailable')
df.isna().sum()
# Out:
# show_id          0
# type             0
# title            0
# director         0
# cast             0
# country          0
# date_added       0
# release_year     0
# rating           0
# duration         3
# listed_in        0
# description      0
# date added      10
# dtype: int64

# %%
df[df.date_added.isnull()]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      8807 non-null   object
#  4   cast          8807 non-null   object
#  5   country       8807 non-null   object
#  6   date_added    8807 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8807 non-null   object
#  9   duration      8807 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
#  12  date added    8797 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(11)
# memory usage: 894.6+ KB

# %%
most_recent_entry_date=df['date_added'].max()
df.fillna({'date_added': most_recent_entry_date}, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      8807 non-null   object
#  4   cast          8807 non-null   object
#  5   country       8807 non-null   object
#  6   date_added    8807 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8807 non-null   object
#  9   duration      8807 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
#  12  date added    8797 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(11)
# memory usage: 894.6+ KB

# %%
df.show_id
# Out:
# 0          s1
# 1          s2
# 2          s3
# 3          s4
# 4          s5
#         ...
# 8802    s8803
# 8803    s8804
# 8804    s8805
# 8805    s8806
# 8806    s8807
# Name: show_id, Length: 8807, dtype: object

# %%
df[df.show_id == 's8803']
# Out:
#      show_id   type   title       director  \
# 8802   s8803  Movie  Zodiac  David Fincher
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
#
#              date_added  release_year rating duration  \
# 8802  November 20, 2019          2007      R  158 min
#
#                            listed_in  \
# 8802  Cult Movies, Dramas, Thrillers
#
#                                             description date added
# 8802  A political cartoonist, a crime reporter and a... 2019-11-20

# %%
df[df.duration.isnull()]
# Out:
#      show_id   type                                 title    director  \
# 5541   s5542  Movie                       Louis C.K. 2017  Louis C.K.
# 5794   s5795  Movie                 Louis C.K.: Hilarious  Louis C.K.
# 5813   s5814  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.
#
#             cast        country          date_added  release_year  rating  \
# 5541  Louis C.K.  United States       April 4, 2017          2017  74 min
# 5794  Louis C.K.  United States  September 16, 2016          2010  84 min
# 5813  Louis C.K.  United States     August 15, 2016          2015  66 min
#
#      duration listed_in                                        description  \
# 5541      NaN    Movies  Louis C.K. muses on religion, eternal love, gi...
# 5794      NaN    Movies  Emmy-winning comedy writer Louis C.K. brings h...
# 5813      NaN    Movies  The comic puts his trademark hilarious/thought...
#
#      date added
# 5541 2017-04-04
# 5794 2016-09-16
# 5813 2016-08-15

# %%
df[df.director == 'Louis C.K.'].head()
# Out:
#      show_id   type                                 title    director  \
# 5541   s5542  Movie                       Louis C.K. 2017  Louis C.K.
# 5794   s5795  Movie                 Louis C.K.: Hilarious  Louis C.K.
# 5813   s5814  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.
#
#             cast        country          date_added  release_year  rating  \
# 5541  Louis C.K.  United States       April 4, 2017          2017  74 min
# 5794  Louis C.K.  United States  September 16, 2016          2010  84 min
# 5813  Louis C.K.  United States     August 15, 2016          2015  66 min
#
#      duration listed_in                                        description  \
# 5541      NaN    Movies  Louis C.K. muses on religion, eternal love, gi...
# 5794      NaN    Movies  Emmy-winning comedy writer Louis C.K. brings h...
# 5813      NaN    Movies  The comic puts his trademark hilarious/thought...
#
#      date added
# 5541 2017-04-04
# 5794 2016-09-16
# 5813 2016-08-15

# %%
df.loc[df['director'] == 'Louis C.K.', 'duration'] = df['rating']
df[df.director == 'Louis C.K.'].head()
# Out:
#      show_id   type                                 title    director  \
# 5541   s5542  Movie                       Louis C.K. 2017  Louis C.K.
# 5794   s5795  Movie                 Louis C.K.: Hilarious  Louis C.K.
# 5813   s5814  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.
#
#             cast        country          date_added  release_year  rating  \
# 5541  Louis C.K.  United States       April 4, 2017          2017  74 min
# 5794  Louis C.K.  United States  September 16, 2016          2010  84 min
# 5813  Louis C.K.  United States     August 15, 2016          2015  66 min
#
#      duration listed_in                                        description  \
# 5541   74 min    Movies  Louis C.K. muses on religion, eternal love, gi...
# 5794   84 min    Movies  Emmy-winning comedy writer Louis C.K. brings h...
# 5813   66 min    Movies  The comic puts his trademark hilarious/thought...
#
#      date added
# 5541 2017-04-04
# 5794 2016-09-16
# 5813 2016-08-15

# %%
df.loc[df['director'] == 'Louis C.K.', 'rating'] = 'unavailable'
df[df.director == 'Louis C.K.'].head()
# Out:
#      show_id   type                                 title    director  \
# 5541   s5542  Movie                       Louis C.K. 2017  Louis C.K.
# 5794   s5795  Movie                 Louis C.K.: Hilarious  Louis C.K.
# 5813   s5814  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.
#
#             cast        country          date_added  release_year  \
# 5541  Louis C.K.  United States       April 4, 2017          2017
# 5794  Louis C.K.  United States  September 16, 2016          2010
# 5813  Louis C.K.  United States     August 15, 2016          2015
#
#            rating duration listed_in  \
# 5541  unavailable   74 min    Movies
# 5794  unavailable   84 min    Movies
# 5813  unavailable   66 min    Movies
#
#                                             description date added
# 5541  Louis C.K. muses on religion, eternal love, gi... 2017-04-04
# 5794  Emmy-winning comedy writer Louis C.K. brings h... 2016-09-16
# ...

# %% [markdown]
# # Data Visualization

# %%
df.type.value_counts()
# Out:
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
sns.countplot(x ='type', data = df)
plt.title('Count vs Type of shows')
# Out:
# Text(0.5, 1.0, 'count vs type of shows')

# %%
df['country'].value_counts().head(10)
# Out:
# United States     2818
# India              972
# unavailable        831
# United Kingdom     419
# Japan              245
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Name: country, dtype: int64

# %%
filtered_df = df[df['country'] != 'unavailable']  # Exclude rows with 'country' labeled as 'unavailable'

plt.figure(figsize=(12, 6))
sns.countplot(y='country', order=filtered_df['country'].value_counts().index[0:10], data=filtered_df)
plt.title('Country-wise Content on Netflix')
plt.xlabel('Count')
plt.ylabel('Country')
plt.show()

# %%
movie_countries = df[df['type'] == 'Movie']
tv_show_countries = df[df['type']=='TV Show']

# %%
movie_countries.head()
# Out:
#    show_id   type                             title  \
# 0       s1  Movie              Dick Johnson Is Dead
# 6       s7  Movie  My Little Pony: A New Generation
# 7       s8  Movie                           Sankofa
# 9      s10  Movie                      The Starling
# 12     s13  Movie                      Je Suis Karl
#
#                          director  \
# 0                 Kirsten Johnson
# 6   Robert Cullen, José Luis Ucha
# 7                    Haile Gerima
# 9                  Theodore Melfi
# 12            Christian Schwochow
#
#                                                  cast  \
# 0                                         unavailable
# 6   Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
#
#                                               country          date_added  \
# ...

# %%
plt.figure(figsize = (12,6))
sns.countplot(y='country',order = df['country'].value_counts().index[0:10],data = movie_countries)
plt.title('Top 10 Countries Producing Movies In NETFLIX');

plt.figure(figsize = (12,6))
sns.countplot(y='country',order = df['country'].value_counts().index[0:10],data = tv_show_countries)
plt.title('Top 10 Countries Producing tv_show_countries In NETFLIX');

# %%
df.rating.value_counts()
# Out:
# TV-MA          3207
# TV-14          2160
# TV-PG           863
# R               799
# PG-13           490
# TV-Y7           334
# TV-Y            307
# PG              287
# TV-G            220
# NR               80
# G                41
# unavailable       7
# TV-Y7-FV          6
# NC-17             3
# UR                3
# Name: rating, dtype: int64

# %%
plt.figure(figsize = (9,6))
sns.countplot(x='rating', order =df['rating'].value_counts().index[0:10],data = df)
plt.title('Ratings of Shows on Netflix vs Count')
# Out:
# Text(0.5, 1.0, 'Ratings of Shows on Netflix vs Count')

# %%
df.release_year.value_counts()[:20]
# Out:
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
# 2021     592
# 2015     560
# 2014     352
# 2013     288
# 2012     237
# 2010     194
# 2011     185
# 2009     152
# 2008     136
# 2006      96
# 2007      88
# 2005      80
# 2004      64
# 2003      61
# 2002      51
# Name: release_year, dtype: int64

# %%
plt.figure(figsize = (10,6))
sns.countplot(x='release_year' , order = df['release_year'].value_counts().index[0:20],data = df)
plt.title('Content Release in years on Netflix vs Count')
# Out:
# Text(0.5, 1.0, 'Content Release in years on Netflix vs Count')

# %%
plt.figure(figsize = (12,8))
sns.countplot(y='listed_in',order = df['listed_in'].value_counts().index[0:20],data = df)
plt.title('Top 20 Genres on Netflix')
# Out:
# Text(0.5, 1.0, 'Top 20 Genres on Netflix')

# %% [markdown]
# # Summary

# %% [markdown]
# *The Netflix Content Analysis project aims to analyze the vast catalog of content available on the Netflix streaming platform. By delving into the data encompassing various genres, regions, release years, and other relevant attributes, this project endeavors to uncover valuable insights and trends within Netflix's content library.
